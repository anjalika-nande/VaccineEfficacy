# %%
### import modules
from utils import plot_comparison

# %% [markdown]
# # Comparing With and Without Waning
#
# Let us now compare the results from running the modified SEIR model with and without waning protection of the vaccines. We compared the difference percentage reduction that was calculated 60 days after vaccination started, and the plots are shown below.
#
# ## 50% efficacy
# ### Measured 30 Days After Vaccination

# %%
# %store -r pre_m30
# %store -r post10_m30
# %store -r post30_m30

# %store -r pre_m30_waning
# %store -r post10_m30_waning
# %store -r post30_m30_waning

fig_30 = plot_comparison(pre_m30, post10_m30, post30_m30, pre_m30_waning, post10_m30_waning, post30_m30_waning, 0.5)

# %% [markdown]
# ### Measured 60 Days After Vaccination

# %%
# %store -r pre_m60
# %store -r post10_m60
# %store -r post30_m60

# %store -r pre_m60_waning
# %store -r post10_m60_waning
# %store -r post30_m60_waning

fig_60 = plot_comparison(pre_m60, post10_m60, post30_m60, pre_m60_waning, post10_m60_waning, post30_m60_waning, 0.5)

# %% [markdown]
# ### Measured 100 Days After Vaccination

# %%
# %store -r pre_m100
# %store -r post10_m100
# %store -r post30_m100

# %store -r pre_m100_waning
# %store -r post10_m100_waning
# %store -r post30_m100_waning

fig_100 = plot_comparison(pre_m100, post10_m100, post30_m100, pre_m100_waning, post10_m100_waning, post30_m100_waning, 0.5)

# %% [markdown]
# ### Measured 200 Days After Vaccination (End of Epidemic)

# %%
# %store -r pre_m200
# %store -r post10_m200
# %store -r post30_m200

# %store -r pre_m200_waning
# %store -r post10_m200_waning
# %store -r post30_m200_waning

fig_200 = plot_comparison(pre_m200, post10_m200, post30_m200, pre_m200_waning, post10_m200_waning, post30_m200_waning, 0.5)

# %% [markdown]
# ## 80% Vaccine Efficacy
# ### Measured 30 Days After Vaccination

# %%
# %store -r pre_m30
# %store -r post10_m30
# %store -r post30_m30

# %store -r pre_m30_waning
# %store -r post10_m30_waning
# %store -r post30_m30_waning

fig_30 = plot_comparison(pre_m30, post10_m30, post30_m30, pre_m30_waning, post10_m30_waning, post30_m30_waning, 0.8)

# %% [markdown]
# ### Measured 60 Days After Vaccination

# %%
# %store -r pre_m60
# %store -r post10_m60
# %store -r post30_m60

# %store -r pre_m60_waning
# %store -r post10_m60_waning
# %store -r post30_m60_waning

fig_60 = plot_comparison(pre_m60, post10_m60, post30_m60, pre_m60_waning, post10_m60_waning, post30_m60_waning, 0.8)

# %% [markdown]
# ### Measured 100 Days After Vaccination

# %%
# %store -r pre_m100
# %store -r post10_m100
# %store -r post30_m100

# %store -r pre_m100_waning
# %store -r post10_m100_waning
# %store -r post30_m100_waning

fig_100 = plot_comparison(pre_m100, post10_m100, post30_m100, pre_m100_waning, post10_m100_waning, post30_m100_waning, 0.8)

# %% [markdown]
# ### Measured 200 Days After Vaccination (End of Epidemic)

# %%
# %store -r pre_m200
# %store -r post10_m200
# %store -r post30_m200

# %store -r pre_m200_waning
# %store -r post10_m200_waning
# %store -r post30_m200_waning

fig_200 = plot_comparison(pre_m200, post10_m200, post30_m200, pre_m200_waning, post10_m200_waning, post30_m200_waning, 0.8)
